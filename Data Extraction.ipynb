# %%
import tarfile
import os

# %%
#Extract Clinical Data
tar = tarfile.open("cis-pd.clinical_data.tar.bz2", "r:bz2")  
tar.extractall()
tar.close()

#Extract label Data
tar = tarfile.open("cis-pd.data_labels.tar.bz2", "r:bz2")  
tar.extractall()
tar.close()

#ancillary_data
tar = tarfile.open("cis-pd.ancillary_data.tar.bz2", "r:bz2")  
tar.extractall()
tar.close()

#testing_data
tar = tarfile.open("cis-pd.testing_data.tar.bz2", "r:bz2")  
tar.extractall()
tar.close()

#training_data
tar = tarfile.open("cis-pd.training_data.tar.bz2", "r:bz2")  
tar.extractall()
tar.close()

# %%
#REAL PD
tar = tarfile.open("real-pd.clinical_data.tar.bz2", "r:bz2")  
tar.extractall()
tar.close()

tar = tarfile.open("real-pd.data_labels.tar.bz2", "r:bz2")  
tar.extractall()
tar.close()

tar = tarfile.open("real-pd.training_data.tar.bz2", "r:bz2")  
tar.extractall()
tar.close()

tar = tarfile.open("real-pd.testing_data.tar.bz2", "r:bz2")  
tar.extractall()
tar.close()

tar = tarfile.open("real-pd.ancillary_data.tar.bz2", "r:bz2")  
tar.extractall()
tar.close()
